# %%
import librosa
import matplotlib.pyplot as plt
import pandas as pd
from librosa import display
import numpy as np


#Baixando audio
path = 'C:/Users/Lenovo/Desktop'
audio_1 = '/sound.wav'

pcora , sr = librosa.load(path+audio_1)

#Olhando para um período do sinal

plt.figure(figsize=(14, 5))
plt.plot(pcora[0:1500000])
plt.grid()
# plt.savefig('image.jpg') 
pcora[0:1500000].display()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-e18570ae9065> in <module>
#      18 plt.grid()
#      19 # plt.savefig('image.jpg')
# ---> 20 pcora[0:1500000].display()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'display'

# %%
sr
# Out:
# 22050
