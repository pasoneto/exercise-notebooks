# %%
import requests
import pandas as pd

# %%
#query
def search_food(query):
    key = 'SPLGeaHg7DTDY1uPjm7lEraw3qdMqr7OTqdHYEea'
    return requests.get(f"https://api.nal.usda.gov/fdc/v1/foods/search?api_key={key}&query={query}").json()

#choose food
def options(dado):
    return [(dado[x]['description'], x) for x in range(len(dado))]

#get info
def info(item, query): #item eh a posicao do alimento que eu quero e.g. oi['foods'][0]
    df = pd.DataFrame(item['foodNutrients'])
    df['alimento'] = query
    try:
        df['ingredients'] = item['ingredients']
    except:
        return df
    
#pipeline
#query -> escolha entre a query -> get info
# Out:
# [("McDONALD'S, McFLURRY with OREO cookies", 0),
#  ('Nabisco, Nabisco Oreo Crunchies, Cookie Crumb Topping', 1),
#  ('Cookie, chocolate sandwich', 2),
#  ('Cookie, chocolate, sandwich, with extra filling', 3),
#  ('Ice cream sandwich', 4),
#  ('Cookie, chocolate sandwich, reduced fat', 5),
#  ('Cookie, vanilla sandwich, extra filling', 6),
#  ('Cookie, chocolate wafer', 7),
#  ('Cookie, vanilla sandwich', 8),
#  ('Snack cake, chocolate, with icing or filling', 9),
#  ('OREO ICED COFFEE, OREO', 10),
#  ('OREO FROZEN DESSERT BARS, OREO', 11),
#  ('OREO FROZEN DESSERT CONES, OREO', 12),
#  ('OREO FUN TREATS CANDY, OREO', 13),
#  ("OREO O'S CEREAL, OREO O'S", 14),
#  ('OREO WAFER OREO 1X18.16 LB', 15),
#  ('OREO COOKIES', 16),
#  ('OREO COOKIES', 17),
#  ('NABISCO OREO COOKIES OREO 1X10.7 OZ', 18),
#  ('NABISCO OREO COOKIES OREO 1X10.700 OZ', 19),
#  ('NABISCO OREO COOKIES OREO 1X45.000 OZ', 20),
#  ('OREO COOKIES - MINI GOLDEN OREO 1X', 21),
#  ('OREO COOKIES GOLDEN OREO 1X20 OZ', 22),
#  ('OREO ICED COFFEE MILK BEVERAGE, OREO', 23),
#  ('OREO THINS COOKIES OREO 1X3.7 OZ', 24),
#  ("GOLDEN OREO O'S CEREAL, GOLDEN OREO O'S", 25),
#  ("MEGA STUF OREO O'S CEREAL, OREO O'S", 26),
#  ('NABISCO OREO THINS COOKIES OREO 1X10.1 OZ', 27),
#  ('OREOS, CHOCOLATE COVERED', 28),
#  ('CHOCOLATE COVERED OREOS', 29),
#  ('CHOCOLATE COVERED OREOS', 30),
#  ('CHOCOLATE COVERED OREOS', 31),
#  ('CHOCOLATE COVERED OREOS', 32),
#  ('CHOCOLATE COVERED OREOS', 33),
#  ('CHOCOLATE COVERED OREOS', 34),
#  ('CHOCOLATE COVERED OREOS', 35),
#  ('MILKA, CHOCOLATE WITH OREO', 36),
#  ('OREO CHOCO-MIX', 37),
#  ('OREO COOKIE PIECES', 38),
#  ('OREO COOKIE PIECES', 39),
#  ('OREO COOKIES VANILLA', 40),
#  ("OREO O'S CEREAL", 41),
#  ('NABISCO OREO BAKING INGREDIENTS OREO CREME 1X50.000 LB', 42),
#  ('NABISCO OREO THINS COOKIES GOLDEN OREO 1X10.1 OZ', 43),
#  ('OREO COOKIE BITS AND VANILLA CREME CANDY, OREO COOKIE', 44),
#  ('OREO COOKIES-CONVENIENCE PACK GOLDEN OREO 1X2.4 OZ', 45),
#  ('NABISCO OREO DOUBLE STUF COOKIES GOLDEN OREO OREO1X4 OZ', 46),
#  ('CHOCOLATE DIPPED OREOS, CHOCOLATE', 47),
#  ('FROZEN OREO DESSERT BAR', 48),
#  ('NABISCO, OREO, CHOCOLATE PIE', 49)]

# %%
oi = search_food("oreo")
info(oi['foods'][0], 'oreo')

# "banana", "laranja", "halls", "oreo", "kibom"
# Out:
# {'foodSearchCriteria': {'query': 'oreo',
#   'generalSearchInput': 'oreo',
#   'pageNumber': 1,
#   'requireAllWords': False},
#  'totalHits': 377,
#  'currentPage': 1,
#  'totalPages': 8,
#  'foods': [{'fdcId': 173304,
#    'description': "McDONALD'S, McFLURRY with OREO cookies",
#    'dataType': 'SR Legacy',
#    'ndbNumber': '21339',
#    'publishedDate': '2019-04-01',
#    'foodNutrients': [{'nutrientId': 1010,
#      'nutrientName': 'Sucrose',
#      'nutrientNumber': '210',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 14.2},
#     {'nutrientId': 1011,
#      'nutrientName': 'Glucose (dextrose)',
#      'nutrientNumber': '211',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.89},
#     {'nutrientId': 1014,
#      'nutrientName': 'Maltose',
#      'nutrientNumber': '214',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.28},
#     {'nutrientId': 1051,
#      'nutrientName': 'Water',
#      'nutrientNumber': '255',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 63.9},
#     {'nutrientId': 2000,
#      'nutrientName': 'Sugars, total including NLEA',
#      'nutrientNumber': '269',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 21.19},
#     {'nutrientId': 1277,
#      'nutrientName': '20:1',
#      'nutrientNumber': '628',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.002},
#     {'nutrientId': 1292,
#      'nutrientName': 'Fatty acids, total monounsaturated',
#      'nutrientNumber': '645',
#      'unitName': 'G',
#      'derivationCode': 'RKI',
#      'derivationDescription': 'Recipe;Known formulation;No adjustments applied, combination of source codes which includes codes other than 1,12,or 6',
#      'value': 1.716},
#     {'nutrientId': 1293,
#      'nutrientName': 'Fatty acids, total polyunsaturated',
#      'nutrientNumber': '646',
#      'unitName': 'G',
#      'derivationCode': 'RKI',
#      'derivationDescription': 'Recipe;Known formulation;No adjustments applied, combination of source codes which includes codes other than 1,12,or 6',
#      'value': 0.364},
#     {'nutrientId': 1299,
#      'nutrientName': '15:0',
#      'nutrientNumber': '652',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.038},
#     {'nutrientId': 1313,
#      'nutrientName': '20:2 n-6 c,c',
#      'nutrientNumber': '672',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.0},
#     {'nutrientId': 1325,
#      'nutrientName': '20:3',
#      'nutrientNumber': '689',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.0},
#     {'nutrientId': 1109,
#      'nutrientName': 'Vitamin E (alpha-tocopherol)',
#      'nutrientNumber': '323',
#      'unitName': 'MG',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.09},
#     {'nutrientId': 1167,
#      'nutrientName': 'Niacin',
#      'nutrientNumber': '406',
#      'unitName': 'MG',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.264},
#     {'nutrientId': 1170,
#      'nutrientName': 'Pantothenic acid',
#      'nutrientNumber': '410',
#      'unitName': 'MG',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.722},
#     {'nutrientId': 1175,
#      'nutrientName': 'Vitamin B-6',
#      'nutrientNumber': '415',
#      'unitName': 'MG',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.058},
#     {'nutrientId': 1262,
#      'nutrientName': '10:0',
#      'nutrientNumber': '610',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.087},
#     {'nutrientId': 1265,
#      'nutrientName': '16:0',
#      'nutrientNumber': '613',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 1.254},
#     {'nutrientId': 1266,
#      'nutrientName': '18:0',
#      'nutrientNumber': '614',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.653},
#     {'nutrientId': 1267,
#      'nutrientName': '20:0',
#      'nutrientNumber': '615',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.01},
#     {'nutrientId': 1268,
#      'nutrientName': '18:1',
#      'nutrientNumber': '617',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 1.639},
#     {'nutrientId': 1269,
#      'nutrientName': '18:2',
#      'nutrientNumber': '618',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.339},
#     {'nutrientId': 1270,
#      'nutrientName': '18:3',
#      'nutrientNumber': '619',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.02},
#     {'nutrientId': 1271,
#      'nutrientName': '20:4',
#      'nutrientNumber': '620',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.005},
#     {'nutrientId': 1004,
#      'nutrientName': 'Total lipid (fat)',
#      'nutrientNumber': '204',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 5.66},
#     {'nutrientId': 1005,
#      'nutrientName': 'Carbohydrate, by difference',
#      'nutrientNumber': '205',
#      'unitName': 'G',
#      'derivationCode': 'RKI',
#      'derivationDescription': 'Recipe;Known formulation;No adjustments applied, combination of source codes which includes codes other than 1,12,or 6',
#      'value': 25.55},
#     {'nutrientId': 1087,
#      'nutrientName': 'Calcium, Ca',
#      'nutrientNumber': '301',
#      'unitName': 'MG',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 129.0},
#     {'nutrientId': 1092,
#      'nutrientName': 'Potassium, K',
#      'nutrientNumber': '306',
#      'unitName': 'MG',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 198.0},
#     {'nutrientId': 1095,
#      'nutrientName': 'Zinc, Zn',
#      'nutrientNumber': '309',
#      'unitName': 'MG',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.5},
#     {'nutrientId': 1003,
#      'nutrientName': 'Protein',
#      'nutrientNumber': '203',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 3.97},
#     {'nutrientId': 1007,
#      'nutrientName': 'Ash',
#      'nutrientNumber': '207',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.92},
#     {'nutrientId': 1012,
#      'nutrientName': 'Fructose',
#      'nutrientNumber': '212',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.18},
#     {'nutrientId': 1013,
#      'nutrientName': 'Lactose',
#      'nutrientNumber': '213',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 5.62},
#     {'nutrientId': 1075,
#      'nutrientName': 'Galactose',
#      'nutrientNumber': '287',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.0},
#     {'nutrientId': 1275,
#      'nutrientName': '16:1',
#      'nutrientNumber': '626',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.042},
#     {'nutrientId': 1300,
#      'nutrientName': '17:0',
#      'nutrientNumber': '653',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.025},
#     {'nutrientId': 1323,
#      'nutrientName': '17:1',
#      'nutrientNumber': '687',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.008},
#     {'nutrientId': 1333,
#      'nutrientName': '15:1',
#      'nutrientNumber': '697',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.0},
#     {'nutrientId': 1079,
#      'nutrientName': 'Fiber, total dietary',
#      'nutrientNumber': '291',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.1},
#     {'nutrientId': 1089,
#      'nutrientName': 'Iron, Fe',
#      'nutrientNumber': '303',
#      'unitName': 'MG',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.61},
#     {'nutrientId': 1090,
#      'nutrientName': 'Magnesium, Mg',
#      'nutrientNumber': '304',
#      'unitName': 'MG',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 14.0},
#     {'nutrientId': 1091,
#      'nutrientName': 'Phosphorus, P',
#      'nutrientNumber': '305',
#      'unitName': 'MG',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 111.0},
#     {'nutrientId': 1093,
#      'nutrientName': 'Sodium, Na',
#      'nutrientNumber': '307',
#      'unitName': 'MG',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 75.0},
#     {'nutrientId': 1098,
#      'nutrientName': 'Copper, Cu',
#      'nutrientNumber': '312',
#      'unitName': 'MG',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.03},
#     {'nutrientId': 1101,
#      'nutrientName': 'Manganese, Mn',
#      'nutrientNumber': '315',
#      'unitName': 'MG',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.042},
#     {'nutrientId': 1104,
#      'nutrientName': 'Vitamin A, IU',
#      'nutrientNumber': '318',
#      'unitName': 'IU',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 323.0},
#     {'nutrientId': 1165,
#      'nutrientName': 'Thiamin',
#      'nutrientNumber': '404',
#      'unitName': 'MG',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.048},
#     {'nutrientId': 1166,
#      'nutrientName': 'Riboflavin',
#      'nutrientNumber': '405',
#      'unitName': 'MG',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.229},
#     {'nutrientId': 1177,
#      'nutrientName': 'Folate, total',
#      'nutrientNumber': '417',
#      'unitName': 'UG',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 5.0},
#     {'nutrientId': 1178,
#      'nutrientName': 'Vitamin B-12',
#      'nutrientNumber': '418',
#      'unitName': 'UG',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.58},
#     {'nutrientId': 1187,
#      'nutrientName': 'Folate, food',
#      'nutrientNumber': '432',
#      'unitName': 'UG',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 5.0},
#     {'nutrientId': 1253,
#      'nutrientName': 'Cholesterol',
#      'nutrientNumber': '601',
#      'unitName': 'MG',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 15.0},
#     {'nutrientId': 1257,
#      'nutrientName': 'Fatty acids, total trans',
#      'nutrientNumber': '605',
#      'unitName': 'G',
#      'derivationCode': 'RKI',
#      'derivationDescription': 'Recipe;Known formulation;No adjustments applied, combination of source codes which includes codes other than 1,12,or 6',
#      'value': 0.565},
#     {'nutrientId': 1258,
#      'nutrientName': 'Fatty acids, total saturated',
#      'nutrientNumber': '606',
#      'unitName': 'G',
#      'derivationCode': 'RKI',
#      'derivationDescription': 'Recipe;Known formulation;No adjustments applied, combination of source codes which includes codes other than 1,12,or 6',
#      'value': 2.577},
#     {'nutrientId': 1261,
#      'nutrientName': '8:0',
#      'nutrientNumber': '609',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.038},
#     {'nutrientId': 1263,
#      'nutrientName': '12:0',
#      'nutrientNumber': '611',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.102},
#     {'nutrientId': 1264,
#      'nutrientName': '14:0',
#      'nutrientNumber': '612',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.367},
#     {'nutrientId': 1273,
#      'nutrientName': '22:0',
#      'nutrientNumber': '624',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.003},
#     {'nutrientId': 1274,
#      'nutrientName': '14:1',
#      'nutrientNumber': '625',
#      'unitName': 'G',
#      'derivationCode': 'RKA',
#      'derivationDescription': 'Recipe; Known formulation; No adjustments applied, combination of source codes 1, 12, and/or 6.',
#      'value': 0.025},
#     {'nutrientId': 1008,
#      'nutrientName': 'Energy',
#      'nutrientNumber': '208',
#      'unitName': 'KCAL',
#      'derivationCode': 'MC',
#      'derivationDescription': 'Manufacturer supplied; Calculated by manufacturer or unknown if analytical or calculated',
#      'value': 165.0},
#     {'nutrientId': 1062,
#      'nutrientName': 'Energy',
#      'nutrientNumber': '268',
#      'unitName': 'kJ',
#      'derivationCode': 'MC',
#      'derivationDescription': 'Manufacturer supplied; Calculated by manufacturer or unknown if analytical or calculated',
#      'value': 690.0}],
#    'allHighlightFields': '',
#    'score': 393.7537},
#   {'fdcId': 175084,
#    'description': 'Nabisco, Nabisco Oreo Crunchies, Cookie Crumb Topping',
#    'dataType': 'SR Legacy',
#    'ndbNumber': '18619',
#    'publishedDate': '2019-04-01',
#    'foodNutrients': [{'nutrientId': 1062,
#      'nutrientName': 'Energy',
#      'nutrientNumber': '268',
#      'unitName': 'kJ',
#      'derivationCode': 'MC',
#      'derivationDescription': 'Manufacturer supplied; Calculated by manufacturer or unknown if analytical or calculated',
#      'value': 1992.0},
#     {'nutrientId': 1087,
#      'nutrientName': 'Calcium, Ca',
#      'nutrientNumber': '301',
#      'unitName': 'MG',
#      'derivationCode': 'MC',
#      'derivationDescription': 'Manufacturer supplied; Calculated by manufacturer or unknown if analytical or calculated',
#      'value': 24.0},
#     {'nutrientId': 1092,
#      'nutrientName': 'Potassium, K',
#      'nutrientNumber': '306',
#      'unitName': 'MG',
#      'derivationCode': 'MC',
#      'derivationDescription': 'Manufacturer supplied; Calculated by manufacturer or unknown if analytical or calculated',
#      'value': 194.0},
#     {'nutrientId': 1095,
#      'nutrientName': 'Zinc, Zn',
#      'nutrientNumber': '309',
#      'unitName': 'MG',
#      'derivationCode': 'MC',
#      'derivationDescription': 'Manufacturer supplied; Calculated by manufacturer or unknown if analytical or calculated',
#      'value': 1.23},
#     {'nutrientId': 1167,
#      'nutrientName': 'Niacin',
#      'nutrientNumber': '406',
#      'unitName': 'MG',
#      'derivationCode': 'MC',
#      'derivationDescription': 'Manufacturer supplied; Calculated by manufacturer or unknown if analytical or calculated',
#      'value': 1.845},
#     {'nutrientId': 1170,
#      'nutrientName': 'Pantothenic acid',
#      'nutrientNumber': '410',
#      'unitName': 'MG',
#      'derivationCode': 'MC',
#      'derivationDescription': 'Manufacturer supplied; Calculated by manufacturer or unknown if analytical or calculated',
#      'value': 0.036},
#     {'nutrientId': 1175,
#      'nutrientName': 'Vitamin B-6',
#      'nutrientNumber': '415',
#      'unitName': 'MG',
#      'derivationCode': 'MC',
#      'derivationDescription': 'Manufacturer supplied; Calculated by manufacturer or unknown if analytical or calculated',
#      'value': 0.032},
#     {'nutrientId': 1292,
#      'nutrientName': 'Fatty acids, total monounsaturated',
#      'nutrientNumber': '645',
#      'unitName': 'G',
#      'derivationCode': 'MC',
#      'derivationDescription': 'Manufacturer supplied; Calculated by manufacturer or unknown if analytical or calculated',
#      'value': 3.17},
#     {'nutrientId': 1293,
#      'nutrientName': 'Fatty acids, total polyunsaturated',
#      'nutrientNumber': '646',
#      'unitName': 'G',
#      'derivationCode': 'MC',
#      'derivationDescription': 'Manufacturer supplied; Calculated by manufacturer or unknown if analytical or calculated',
#      'value': 0.82},
#     {'nutrientId': 1005,
#      'nutrientName': 'Carbohydrate, by difference',
#      'nutrientNumber': '205',
#      'unitName': 'G',
#      'derivationCode': 'MC',
#      'derivationDescription': 'Manufacturer supplied; Calculated by manufacturer or unknown if analytical or calculated',
#      'value': 70.23},
#     {'nutrientId': 1008,
#      'nutrientName': 'Energy',
#      'nutrientNumber': '208',
#      'unitName': 'KCAL',
#      'derivationCode': 'MC',
#      'derivationDescription': 'Manufacturer supplied; Calculated by manufacturer or unknown if analytical or calculated',
#      'value': 476.0},
#     {'nutrientId': 1051,
#      'nutrientName': 'Water',
#      'nutrientNumber': '255',
#      'unitName': 'G',
#      'derivationCode': 'MC',
#      'derivationDescription': 'Manufacturer supplied; Calculated by manufacturer or unknown if analytical or calculated',
#      'value': 1.57},
#     {'nutrientId': 1079,
#      'nutrientName': 'Fiber, total dietary',
#      'nutrientNumber': '291',
#      'unitName': 'G',
#      'derivationCode': 'MC',
#      'derivationDescription': 'Manufacturer supplied; Calculated by manufacturer or unknown if analytical or calculated',
#      'value': 3.2},
#     {'nutrientId': 1089,
#      'nutrientName': 'Iron, Fe',
#      'nutrientNumber': '303',
#      'unitName': 'MG',
#      'derivationCode': 'MC',
#      'derivationDescription': 'Manufacturer supplied; Calculated by manufacturer or unknown if analytical or calculated',
#      'value': 4.9},
#     {'nutrientId': 1090,
#      'nutrientName': 'Magnesium, Mg',
#      'nutrientNumber': '304',
#      'unitName': 'MG',
#      'derivationCode': 'MC',
#      'derivationDescription': 'Manufacturer supplied; Calculated by manufacturer or unknown if analytical or calculated',
#      'value': 48.0},
#     {'nutrientId': 1091,
#      'nutrientName': 'Phosphorus, P',
#      'nutrientNumber': '305',
#      'unitName': 'MG',
#      'derivationCode': 'MC',
#      'derivationDescription': 'Manufacturer supplied; Calculated by manufacturer or unknown if analytical or calculated',
#      'value': 103.0},
#     {'nutrientId': 1093,
#      'nutrientName': 'Sodium, Na',
#      'nutrientNumber': '307',
#      'unitName': 'MG',
#      'derivationCode': 'MC',
#      'derivationDescription': 'Manufacturer supplied; Calculated by manufacturer or unknown if analytical or calculated',
#      'value': 528.0},
#     {'nutrientId': 1098,
#      'nutrientName': 'Copper, Cu',
#      'nutrientNumber': '312',
#      'unitName': 'MG',
#      'derivationCode': 'MC',
#      'derivationDescription': 'Manufacturer supplied; Calculated by manufacturer or unknown if analytical or calculated',
#      'value': 0.27},
#     {'nutrientId': 1104,
#      'nutrientName': 'Vitamin A, IU',
#      'nutrientNumber': '318',
#      'unitName': 'IU',
#      'derivationCode': 'MC',
#      'derivationDescription': 'Manufacturer supplied; Calculated by manufacturer or unknown if analytical or calculated',
#      'value': 3.0},
#     {'nutrientId': 1165,
#      'nutrientName': 'Thiamin',
#      'nutrientNumber': '404',
#      'unitName': 'MG',
#      'derivationCode': 'MC',
#      'derivationDescription': 'Manufacturer supplied; Calculated by manufacturer or unknown if analytical or calculated',
#      'value': 0.122},
#     {'nutrientId': 1166,
#      'nutrientName': 'Riboflavin',
#      'nutrientNumber': '405',
#      'unitName': 'MG',
#      'derivationCode': 'MC',
#      'derivationDescription': 'Manufacturer supplied; Calculated by manufacturer or unknown if analytical or calculated',
#      'value': 0.165},
#     {'nutrientId': 1177,
#      'nutrientName': 'Folate, total',
#      'nutrientNumber': '417',
#      'unitName': 'UG',
#      'derivationCode': 'MC',
#      'derivationDescription': 'Manufacturer supplied; Calculated by manufacturer or unknown if analytical or calculated',
#      'value': 30.0},
#     {'nutrientId': 1178,
#      'nutrientName': 'Vitamin B-12',
#      'nutrientNumber': '418',
#      'unitName': 'UG',
#      'derivationCode': 'MC',
#      'derivationDescription': 'Manufacturer supplied; Calculated by manufacturer or unknown if analytical or calculated',
#      'value': 0.02},
#     {'nutrientId': 1003,
#      'nutrientName': 'Protein',
#      'nutrientNumber': '203',
#      'unitName': 'G',
#      'derivationCode': 'MC',
#      'derivationDescription': 'Manufacturer supplied; Calculated by manufacturer or unknown if analytical or calculated',
#      'value': 4.78},
#     {'nutrientId': 1004,
#      'nutrientName': 'Total lipid (fat)',
#      'nutrientNumber': '204',
#      'unitName': 'G',
#      'derivationCode': 'A',
#      'derivationDescription': 'Analytical',
#      'value': 21.5},
#     {'nutrientId': 1258,
#      'nutrientName': 'Fatty acids, total saturated',
#      'nutrientNumber': '606',
#      'unitName': 'G',
#      'derivationCode': 'A',
#      'derivationDescription': 'Analytical',
#      'value': 4.14},
#     {'nutrientId': 1007,
#      'nutrientName': 'Ash',
#      'nutrientNumber': '207',
#      'unitName': 'G',
#      'derivationCode': 'A',
#      'derivationDescription': 'Analytical',
#      'value': 1.9},
#     {'nutrientId': 2000,
#      'nutrientName': 'Sugars, total including NLEA',
#      'nutrientNumber': '269',
#      'unitName': 'G',
#      'derivationCode': 'A',
#      'derivationDescription': 'Analytical',
#      'value': 36.0},
#     {'nutrientId': 1299,
#      'nutrientName': '15:0',
#      'nutrientNumber': '652',
#      'unitName': 'G',
#      'derivationCode': 'A',
#      'derivationDescription': 'Analytical',
#      'value': 0.01},
#     {'nutrientId': 1325,
#      'nutrientName': '20:3',
#      'nutrientNumber': '689',
#      'unitName': 'G',
#      'derivationCode': 'A',
#      'derivationDescription': 'Analytical',
#      'value': 0.01},
#     {'nutrientId': 1262,
#      'nutrientName': '10:0',
#      'nutrientNumber': '610',
#      'unitName': 'G',
#      'derivationCode': 'A',
#      'derivationDescription': 'Analytical',
#      'value': 0.009},
#     {'nutrientId': 1265,
#      'nutrientName': '16:0',
#      'nutrientNumber': '613',
#      'unitName': 'G',
#      'derivationCode': 'A',
#      'derivationDescription': 'Analytical',
#      'value': 2.192},
#     {'nutrientId': 1266,
#      'nutrientName': '18:0',
#      'nutrientNumber': '614',
#      'unitName': 'G',
#      'derivationCode': 'A',
#      'derivationDescription': 'Analytical',
#      'value': 1.79},
#     {'nutrientId': 1267,
#      'nutrientName': '20:0',
#      'nutrientNumber': '615',
#      'unitName': 'G',
#      'derivationCode': 'A',
#      'derivationDescription': 'Analytical',
#      'value': 0.077},
#     {'nutrientId': 1268,
#      'nutrientName': '18:1',
#      'nutrientNumber': '617',
#      'unitName': 'G',
#      'derivationCode': 'A',
#      'derivationDescription': 'Analytical',
#      'value': 11.101},
#     {'nutrientId': 1269,
#      'nutrientName': '18:2',
#      'nutrientNumber': '618',
#      'unitName': 'G',
#      'derivationCode': 'A',
#      'derivationDescription': 'Analytical',
#      'value': 2.066},
#     {'nutrientId': 1270,
#      'nutrientName': '18:3',
#      'nutrientNumber': '619',
#      'unitName': 'G',
#      'derivationCode': 'A',
#      'derivationDescription': 'Analytical',
#      'value': 0.096},
#     {'nutrientId': 1271,
#      'nutrientName': '20:4',
#      'nutrientNumber': '620',
#      'unitName': 'G',
#      'derivationCode': 'A',
#      'derivationDescription': 'Analytical',
#      'value': 0.01},
#     {'nutrientId': 1277,
#      'nutrientName': '20:1',
#      'nutrientNumber': '628',
#      'unitName': 'G',
#      'derivationCode': 'A',
#      'derivationDescription': 'Analytical',
#      'value': 0.067},
#     {'nutrientId': 1261,
#      'nutrientName': '8:0',
#      'nutrientNumber': '609',
#      'unitName': 'G',
#      'derivationCode': 'A',
#      'derivationDescription': 'Analytical',
#      'value': 0.009},
#     {'nutrientId': 1263,
#      'nutrientName': '12:0',
#      'nutrientNumber': '611',
#      'unitName': 'G',
#      'derivationCode': 'A',
#      'derivationDescription': 'Analytical',
#      'value': 0.009},
#     {'nutrientId': 1264,
#      'nutrientName': '14:0',
#      'nutrientNumber': '612',
#      'unitName': 'G',
#      'derivationCode': 'A',
#      'derivationDescription': 'Analytical',
#      'value': 0.009},
#     {'nutrientId': 1273,
#      'nutrientName': '22:0',
#      'nutrientNumber': '624',
#      'unitName': 'G',
#      'derivationCode': 'A',
#      'derivationDescription': 'Analytical',
#      'value': 0.067},
#     {'nutrientId': 1274,
#      'nutrientName': '14:1',
#      'nutrientNumber': '625',
#      'unitName': 'G',
#      'derivationCode': 'A',
#      'derivationDescription': 'Analytical',
#      'value': 0.009},
#     {'nutrientId': 1275,
#      'nutrientName': '16:1',
#      'nutrientNumber': '626',
#      'unitName': 'G',
#      'derivationCode': 'A',
#      'derivationDescription': 'Analytical',
#      'value': 0.029},
#     {'nutrientId': 1300,
#      'nutrientName': '17:0',
#      'nutrientNumber': '653',
#      'unitName': 'G',
#      'derivationCode': 'A',
#      'derivationDescription': 'Analytical',
#      'value': 0.019},
#     {'nutrientId': 1323,
#      'nutrientName': '17:1',
#      'nutrientNumber': '687',
#      'unitName': 'G',
#      'derivationCode': 'A',
#      'derivationDescription': 'Analytical',
#      'value': 0.01},
#     {'nutrientId': 1187,
#      'nutrientName': 'Folate, food',
#      'nutrientNumber': '432',
#      'unitName': 'UG',
#      'derivationCode': 'MC',
#      'derivationDescription': 'Manufacturer supplied; Calculated by manufacturer or unknown if analytical or calculated',
#      'value': 30.0}],
#    'allHighlightFields': '',
#    'score': 311.0994},
#   {'fdcId': 784848,
#    'description': 'Cookie, chocolate sandwich',
#    'additionalDescriptions': 'Oreo',
#    'dataType': 'Survey (FNDDS)',
#    'foodCode': '53209015',
#    'publishedDate': '2020-04-01',
#    'foodNutrients': [{'nutrientId': 1003,
#      'nutrientName': 'Protein',
#      'nutrientNumber': '203',
#      'unitName': 'G',
#      'value': 5.21},
#     {'nutrientId': 1004,
#      'nutrientName': 'Total lipid (fat)',
#      'nutrientNumber': '204',
#      'unitName': 'G',
#      'value': 19.14},
#     {'nutrientId': 1005,
#      'nutrientName': 'Carbohydrate, by difference',
#      'nutrientNumber': '205',
#      'unitName': 'G',
#      'value': 71.0},
#     {'nutrientId': 1008,
#      'nutrientName': 'Energy',
#      'nutrientNumber': '208',
#      'unitName': 'KCAL',
#      'value': 464.0},
#     {'nutrientId': 1018,
#      'nutrientName': 'Alcohol, ethyl',
#      'nutrientNumber': '221',
#      'unitName': 'G',
#      'value': 0.0},
#     {'nutrientId': 1051,
#      'nutrientName': 'Water',
#      'nutrientNumber': '255',
#      'unitName': 'G',
#      'value': 3.11},
#     {'nutrientId': 1057,
#      'nutrientName': 'Caffeine',
#      'nutrientNumber': '262',
#      'unitName': 'MG',
#      'value': 5.0},
#     {'nutrientId': 1058,
#      'nutrientName': 'Theobromine',
#      'nutrientNumber': '263',
#      'unitName': 'MG',
#      'value': 184.0},
#     {'nutrientId': 2000,
#      'nutrientName': 'Sugars, total including NLEA',
#      'nutrientNumber': '269',
#      'unitName': 'G',
#      'value': 40.67},
#     {'nutrientId': 1079,
#      'nutrientName': 'Fiber, total dietary',
#      'nutrientNumber': '291',
#      'unitName': 'G',
#      'value': 2.9},
#     {'nutrientId': 1087,
#      'nutrientName': 'Calcium, Ca',
#      'nutrientNumber': '301',
#      'unitName': 'MG',
#      'value': 21.0},
#     {'nutrientId': 1089,
#      'nutrientName': 'Iron, Fe',
#      'nutrientNumber': '303',
#      'unitName': 'MG',
#      'value': 12.14},
#     {'nutrientId': 1090,
#      'nutrientName': 'Magnesium, Mg',
#      'nutrientNumber': '304',
#      'unitName': 'MG',
#      'value': 47.0},
#     {'nutrientId': 1091,
#      'nutrientName': 'Phosphorus, P',
#      'nutrientNumber': '305',
#      'unitName': 'MG',
#      'value': 93.0},
#     {'nutrientId': 1092,
#      'nutrientName': 'Potassium, K',
#      'nutrientNumber': '306',
#      'unitName': 'MG',
#      'value': 234.0},
#     {'nutrientId': 1093,
#      'nutrientName': 'Sodium, Na',
#      'nutrientNumber': '307',
#      'unitName': 'MG',
#      'value': 388.0},
#     {'nutrientId': 1095,
#      'nutrientName': 'Zinc, Zn',
#      'nutrientNumber': '309',
#      'unitName': 'MG',
#      'value': 0.74},
#     {'nutrientId': 1098,
#      'nutrientName': 'Copper, Cu',
#      'nutrientNumber': '312',
#      'unitName': 'MG',
#      'value': 0.334},
#     {'nutrientId': 1103,
#      'nutrientName': 'Selenium, Se',
#      'nutrientNumber': '317',
#      'unitName': 'UG',
#      'value': 5.2},
#     {'nutrientId': 1105,
#      'nutrientName': 'Retinol',
#      'nutrientNumber': '319',
#      'unitName': 'UG',
#      'value': 0.0},
#     {'nutrientId': 1106,
#      'nutrientName': 'Vitamin A, RAE',
#      'nutrientNumber': '320',
#      'unitName': 'UG',
#      'value': 1.0},
#     {'nutrientId': 1107,
#      'nutrientName': 'Carotene, beta',
#      'nutrientNumber': '321',
#      'unitName': 'UG',
#      'value': 0.0},
#     {'nutrientId': 1108,
#      'nutrientName': 'Carotene, alpha',
#      'nutrientNumber': '322',
#      'unitName': 'UG',
#      'value': 0.0},
#     {'nutrientId': 1109,
#      'nutrientName': 'Vitamin E (alpha-tocopherol)',
#      'nutrientNumber': '323',
#      'unitName': 'MG',
#      'value': 2.47},
#     {'nutrientId': 1114,
#      'nutrientName': 'Vitamin D (D2 + D3)',
#      'nutrientNumber': '328',
#      'unitName': 'UG',
#      'value': 0.0},
#     {'nutrientId': 1120,
#      'nutrientName': 'Cryptoxanthin, beta',
#      'nutrientNumber': '334',
#      'unitName': 'UG',
#      'value': 0.0},
#     {'nutrientId': 1122,
#      'nutrientName': 'Lycopene',
#      'nutrientNumber': '337',
#      'unitName': 'UG',
#      'value': 0.0},
#     {'nutrientId': 1123,
#      'nutrientName': 'Lutein + zeaxanthin',
#      'nutrientNumber': '338',
#      'unitName': 'UG',
#      'value': 4.0},
#     {'nutrientId': 1162,
#      'nutrientName': 'Vitamin C, total ascorbic acid',
#      'nutrientNumber': '401',
#      'unitName': 'MG',
#      'value': 0.0},
#     {'nutrientId': 1165,
#      'nutrientName': 'Thiamin',
#      'nutrientNumber': '404',
#      'unitName': 'MG',
#      'value': 0.197},
#     {'nutrientId': 1166,
#      'nutrientName': 'Riboflavin',
#      'nutrientNumber': '405',
#      'unitName': 'MG',
#      'value': 0.238},
#     {'nutrientId': 1167,
#      'nutrientName': 'Niacin',
#      'nutrientNumber': '406',
#      'unitName': 'MG',
#      'value': 2.603},
#     {'nutrientId': 1175,
#      'nutrientName': 'Vitamin B-6',
#      'nutrientNumber': '415',
#      'unitName': 'MG',
#      'value': 0.023},
#     {'nutrientId': 1177,
#      'nutrientName': 'Folate, total',
#      'nutrientNumber': '417',
#      'unitName': 'UG',
#      'value': 61.0},
#     {'nutrientId': 1178,
#      'nutrientName': 'Vitamin B-12',
#      'nutrientNumber': '418',
#      'unitName': 'UG',
#      'value': 0.0},
#     {'nutrientId': 1180,
#      'nutrientName': 'Choline, total',
#      'nutrientNumber': '421',
#      'unitName': 'MG',
#      'value': 19.2},
#     {'nutrientId': 1185,
#      'nutrientName': 'Vitamin K (phylloquinone)',
#      'nutrientNumber': '430',
#      'unitName': 'UG',
#      'value': 27.4},
#     {'nutrientId': 1186,
#      'nutrientName': 'Folic acid',
#      'nutrientNumber': '431',
#      'unitName': 'UG',
#      'value': 58.0},
#     {'nutrientId': 1187,
#      'nutrientName': 'Folate, food',
#      'nutrientNumber': '432',
#      'unitName': 'UG',
#      'value': 3.0},
#     {'nutrientId': 1190,
#      'nutrientName': 'Folate, DFE',
#      'nutrientNumber': '435',
#      'unitName': 'UG',
#      'value': 102.0},
#     {'nutrientId': 1242,
#      'nutrientName': 'Vitamin E, added',
#      'nutrientNumber': '573',
#      'unitName': 'MG',
#      'value': 0.0},
#     {'nutrientId': 1246,
#      'nutrientName': 'Vitamin B-12, added',
#      'nutrientNumber': '578',
#      'unitName': 'UG',
#      'value': 0.0},
#     {'nutrientId': 1253,
#      'nutrientName': 'Cholesterol',
#      'nutrientNumber': '601',
#      'unitName': 'MG',
#      'value': 0.0},
#     {'nutrientId': 1258,
#      'nutrientName': 'Fatty acids, total saturated',
#      'nutrientNumber': '606',
#      'unitName': 'G',
#      'value': 5.649},
#     {'nutrientId': 1259,
#      'nutrientName': '4:0',
#      'nutrientNumber': '607',
#      'unitName': 'G',
#      'value': 0.0},
#     {'nutrientId': 1260,
#      'nutrientName': '6:0',
#      'nutrientNumber': '608',
#      'unitName': 'G',
#      'value': 0.0},
#     {'nutrientId': 1261,
#      'nutrientName': '8:0',
#      'nutrientNumber': '609',
#      'unitName': 'G',
#      'value': 0.003},
#     {'nutrientId': 1262,
#      'nutrientName': '10:0',
#      'nutrientNumber': '610',
#      'unitName': 'G',
#      'value': 0.011},
#     {'nutrientId': 1263,
#      'nutrientName': '12:0',
#      'nutrientNumber': '611',
#      'unitName': 'G',
#      'value': 0.045},
#     {'nutrientId': 1264,
#      'nutrientName': '14:0',
#      'nutrientNumber': '612',
#      'unitName': 'G',
#      'value': 0.111},
#     {'nutrientId': 1265,
#      'nutrientName': '16:0',
#      'nutrientNumber': '613',
#      'unitName': 'G',
#      'value': 4.449},
#     {'nutrientId': 1266,
#      'nutrientName': '18:0',
#      'nutrientNumber': '614',
#      'unitName': 'G',
#      'value': 0.857},
#     {'nutrientId': 1268,
#      'nutrientName': '18:1',
#      'nutrientNumber': '617',
#      'unitName': 'G',
#      'value': 9.111},
#     {'nutrientId': 1269,
#      'nutrientName': '18:2',
#      'nutrientNumber': '618',
#      'unitName': 'G',
#      'value': 3.253},
#     {'nutrientId': 1270,
#      'nutrientName': '18:3',
#      'nutrientNumber': '619',
#      'unitName': 'G',
#      'value': 0.298},
#     {'nutrientId': 1271,
#      'nutrientName': '20:4',
#      'nutrientNumber': '620',
#      'unitName': 'G',
#      'value': 0.004},
#     {'nutrientId': 1272,
#      'nutrientName': '22:6 n-3 (DHA)',
#      'nutrientNumber': '621',
#      'unitName': 'G',
#      'value': 0.0},
#     {'nutrientId': 1275,
#      'nutrientName': '16:1',
#      'nutrientNumber': '626',
#      'unitName': 'G',
#      'value': 0.036},
#     {'nutrientId': 1276,
#      'nutrientName': '18:4',
#      'nutrientNumber': '627',
#      'unitName': 'G',
#      'value': 0.0},
#     {'nutrientId': 1277,
#      'nutrientName': '20:1',
#      'nutrientNumber': '628',
#      'unitName': 'G',
#      'value': 0.12},
#     {'nutrientId': 1278,
#      'nutrientName': '20:5 n-3 (EPA)',
#      'nutrientNumber': '629',
#      'unitName': 'G',
#      'value': 0.0},
#     {'nutrientId': 1279,
#      'nutrientName': '22:1',
#      'nutrientNumber': '630',
#      'unitName': 'G',
#      'value': 0.003},
#     {'nutrientId': 1280,
#      'nutrientName': '22:5 n-3 (DPA)',
#      'nutrientNumber': '631',
#      'unitName': 'G',
#      'value': 0.0},
#     {'nutrientId': 1292,
#      'nutrientName': 'Fatty acids, total monounsaturated',
#      'nutrientNumber': '645',
#      'unitName': 'G',
#      'value': 9.278},
#     {'nutrientId': 1293,
#      'nutrientName': 'Fatty acids, total polyunsaturated',
#      'nutrientNumber': '646',
#      'unitName': 'G',
#      'value': 3.561}],
#    'allHighlightFields': '<b>Includes</b>: <em>Oreo</em>',
#    'score': 31.259438},
#   {'fdcId': 784850,
#    'description': 'Cookie, chocolate, sandwich, with extra filling',
#    'additionalDescriptions': 'Double Stuff Oreo; Fudge covered Oreos; chocolate sandwich with coating',
#    'dataType': 'Survey (FNDDS)',
#    'foodCode': '53209100',
#    'publishedDate': '2020-04-01',
#    'foodNutrients': [{'nutrientId': 1003,
#      'nutrientName': 'Protein',
#      'nutrientNumber': '203',
#      'unitName': 'G',
#      'value': 4.33},
#     {'nutrientId': 1004,
#      'nutrientName': 'Total lipid (fat)',
#      'nutrientNumber': '204',
#      'unitName': 'G',
#      'value': 24.52},
#     {'nutrientId': 1005,
#      'nutrientName': 'Carbohydrate, by difference',
#      'nutrientNumber': '205',
#      'unitName': 'G',
#      'value': 68.2},
#     {'nutrientId': 1008,
#      'nutrientName': 'Energy',
#      'nutrientNumber': '208',
#      'unitName': 'KCAL',
#      'value': 497.0},
#     {'nutrientId': 1018,
#      'nutrientName': 'Alcohol, ethyl',
#      'nutrientNumber': '221',
#      'unitName': 'G',
#      'value': 0.0},
#     {'nutrientId': 1051,
#      'nutrientName': 'Water',
#      'nutrientNumber': '255',
#      'unitName': 'G',
#      'value': 1.65},
#     {'nutrientId': 1057,
#      'nutrientName': 'Caffeine',
#      'nutrientNumber': '262',
#      'unitName': 'MG',
#      'value': 6.0},
#     {'nutrientId': 1058,
#      'nutrientName': 'Theobromine',
#      'nutrientNumber': '263',
#      'unitName': 'MG',
#      'value': 190.0},
#     {'nutrientId': 2000,
#      'nutrientName': 'Sugars, total including NLEA',
#      'nutrientNumber': '269',
#      'unitName': 'G',
#      'value': 46.0},
#     {'nutrientId': 1079,
#      'nutrientName': 'Fiber, total dietary',
#      'nutrientNumber': '291',
#      'unitName': 'G',
#      'value': 2.7},
#     {'nutrientId': 1087,
#      'nutrientName': 'Calcium, Ca',
#      'nutrientNumber': '301',
#      'unitName': 'MG',
#      'value': 16.0},
#     {'nutrientId': 1089,
#      'nutrientName': 'Iron, Fe',
#      'nutrientNumber': '303',
#      'unitName': 'MG',
#      'value': 7.8},
#     {'nutrientId': 1090,
#      'nutrientName': 'Magnesium, Mg',
#      'nutrientNumber': '304',
#      'unitName': 'MG',
#      'value': 36.0},
#     {'nutrientId': 1091,
#      'nutrientName': 'Phosphorus, P',
#      'nutrientNumber': '305',
#      'unitName': 'MG',
#      'value': 69.0},
#     {'nutrientId': 1092,
#      'nutrientName': 'Potassium, K',
#      'nutrientNumber': '306',
#      'unitName': 'MG',
#      'value': 137.0},
#     {'nutrientId': 1093,
#      'nutrientName': 'Sodium, Na',
#      'nutrientNumber': '307',
#      'unitName': 'MG',
#      'value': 351.0},
#     {'nutrientId': 1095,
#      'nutrientName': 'Zinc, Zn',
#      'nutrientNumber': '309',
#      'unitName': 'MG',
#      'value': 0.78},
#     {'nutrientId': 1098,
#      'nutrientName': 'Copper, Cu',
#      'nutrientNumber': '312',
#      'unitName': 'MG',
#      'value': 0.337},
#     {'nutrientId': 1103,
#      'nutrientName': 'Selenium, Se',
#      'nutrientNumber': '317',
#      'unitName': 'UG',
#      'value': 8.1},
#     {'nutrientId': 1105,
#      'nutrientName': 'Retinol',
#      'nutrientNumber': '319',
#      'unitName': 'UG',
#      'value': 0.0},
#     {'nutrientId': 1106,
#      'nutrientName': 'Vitamin A, RAE',
#      'nutrientNumber': '320',
#      'unitName': 'UG',
#      'value': 0.0},
#     {'nutrientId': 1107,
#      'nutrientName': 'Carotene, beta',
#      'nutrientNumber': '321',
#      'unitName': 'UG',
#      'value': 0.0},
#     {'nutrientId': 1108,
#      'nutrientName': 'Carotene, alpha',
#      'nutrientNumber': '322',
#      'unitName': 'UG',
#      'value': 0.0},
#     {'nutrientId': 1109,
#      'nutrientName': 'Vitamin E (alpha-tocopherol)',
#      'nutrientNumber': '323',
#      'unitName': 'MG',
#      'value': 1.89},
#     {'nutrientId': 1114,
#      'nutrientName': 'Vitamin D (D2 + D3)',
#      'nutrientNumber': '328',
#      'unitName': 'UG',
#      'value': 0.0},
#     {'nutrientId': 1120,
#      'nutrientName': 'Cryptoxanthin, beta',
#      'nutrientNumber': '334',
#      'unitName': 'UG',
#      'value': 0.0},
#     {'nutrientId': 1122,
#      'nutrientName': 'Lycopene',
#      'nutrientNumber': '337',
#      'unitName': 'UG',
#      'value': 0.0},
#     {'nutrientId': 1123,
#      'nutrientName': 'Lutein + zeaxanthin',
#      'nutrientNumber': '338',
#      'unitName': 'UG',
#      'value': 3.0},
#     {'nutrientId': 1162,
#      'nutrientName': 'Vitamin C, total ascorbic acid',
#      'nutrientNumber': '401',
#      'unitName': 'MG',
#      'value': 0.0},
#     {'nutrientId': 1165,
#      'nutrientName': 'Thiamin',
#      'nutrientNumber': '404',
#      'unitName': 'MG',
#      'value': 0.115},
#     {'nutrientId': 1166,
#      'nutrientName': 'Riboflavin',
#      'nutrientNumber': '405',
#      'unitName': 'MG',
#      'value': 0.12},
#     {'nutrientId': 1167,
#      'nutrientName': 'Niacin',
#      'nutrientNumber': '406',
#      'unitName': 'MG',
#      'value': 1.937},
#     {'nutrientId': 1175,
#      'nutrientName': 'Vitamin B-6',
#      'nutrientNumber': '415',
#      'unitName': 'MG',
#      'value': 0.0},
#     {'nutrientId': 1177,
#      'nutrientName': 'Folate, total',
#      'nutrientNumber': '417',
#      'unitName': 'UG',
#      'value': 46.0},
#     {'nutrientId': 1178,
#      'nutrientName': 'Vitamin B-12',
#      'nutrientNumber': '418',
#      'unitName': 'UG',
#      'value': 0.02},
#     {'nutrientId': 1180,
#      'nutrientName': 'Choline, total',
#      'nutrientNumber': '421',
#      'unitName': 'MG',
#      'value': 3.3},
#     {'nutrientId': 1185,
#      'nutrientName': 'Vitamin K (phylloquinone)',
#      'nutrientNumber': '430',
#      'unitName': 'UG',
#      'value': 6.2},
#     {'nutrientId': 1186,
#      'nutrientName': 'Folic acid',
#      'nutrientNumber': '431',
#      'unitName': 'UG',
#      'value': 34.0},
#     {'nutrientId': 1187,
#      'nutrientName': 'Folate, food',
#      'nutrientNumber': '432',
#      'unitName': 'UG',
#      'value': 12.0},
#     {'nutrientId': 1190,
#      'nutrientName': 'Folate, DFE',
#      'nutrientNumber': '435',
#      'unitName': 'UG',
#      'value': 69.0},
#     {'nutrientId': 1242,
#      'nutrientName': 'Vitamin E, added',
#      'nutrientNumber': '573',
#      'unitName': 'MG',
#      'value': 0.0},
#     {'nutrientId': 1246,
#      'nutrientName': 'Vitamin B-12, added',
#      'nutrientNumber': '578',
#      'unitName': 'UG',
#      'value': 0.0},
#     {'nutrientId': 1253,
#      'nutrientName': 'Cholesterol',
#      'nutrientNumber': '601',
#      'unitName': 'MG',
#      'value': 0.0},
#     {'nutrientId': 1258,
#      'nutrientName': 'Fatty acids, total saturated',
#      'nutrientNumber': '606',
#      'unitName': 'G',
#      'value': 5.454},
#     {'nutrientId': 1259,
#      'nutrientName': '4:0',
#      'nutrientNumber': '607',
#      'unitName': 'G',
#      'value': 0.0},
#     {'nutrientId': 1260,
#      'nutrientName': '6:0',
#      'nutrientNumber': '608',
#      'unitName': 'G',
#      'value': 0.0},
#     {'nutrientId': 1261,
#      'nutrientName': '8:0',
#      'nutrientNumber': '609',
#      'unitName': 'G',
#      'value': 0.0},
#     {'nutrientId': 1262,
#      'nutrientName': '10:0',
#      'nutrientNumber': '610',
#      'unitName': 'G',
#      'value': 0.0},
#     {'nutrientId': 1263,
#      'nutrientName': '12:0',
#      'nutrientNumber': '611',
#      'unitName': 'G',
#      'value': 0.0},
#     {'nutrientId': 1264,
#      'nutrientName': '14:0',
#      'nutrientNumber': '612',
#      'unitName': 'G',
#      'value': 0.021},
#     {'nutrientId': 1265,
#      'nutrientName': '16:0',
#      'nutrientNumber': '613',
#      'unitName': 'G',
#      'value': 2.774},
#     {'nutrientId': 1266,
#      'nutrientName': '18:0',
#      'nutrientNumber': '614',
#      'unitName': 'G',
#      'value': 2.436},
#     {'nutrientId': 1268,
#      'nutrientName': '18:1',
#      'nutrientNumber': '617',
#      'unitName': 'G',
#      'value': 16.042},
#     {'nutrientId': 1269,
#      'nutrientName': '18:2',
#      'nutrientNumber': '618',
#      'unitName': 'G',
#      'value': 2.418},
#     {'nutrientId': 1270,
#      'nutrientName': '18:3',
#      'nutrientNumber': '619',
#      'unitName': 'G',
#      'value': 0.053},
#     {'nutrientId': 1271,
#      'nutrientName': '20:4',
#      'nutrientNumber': '620',
#      'unitName': 'G',
#      'value': 0.0},
#     {'nutrientId': 1272,
#      'nutrientName': '22:6 n-3 (DHA)',
#      'nutrientNumber': '621',
#      'unitName': 'G',
#      'value': 0.0},
#     {'nutrientId': 1275,
#      'nutrientName': '16:1',
#      'nutrientNumber': '626',
#      'unitName': 'G',
#      'value': 0.0},
#     {'nutrientId': 1276,
#      'nutrientName': '18:4',
#      'nutrientNumber': '627',
#      'unitName': 'G',
#      'value': 0.0},
#     {'nutrientId': 1277,
#      'nutrientName': '20:1',
#      'nutrientNumber': '628',
#      'unitName': 'G',
#      'value': 0.034},
#     {'nutrientId': 1278,
#      'nutrientName': '20:5 n-3 (EPA)',
#      'nutrientNumber': '629',
#      'unitName': 'G',
#      'value': 0.0},
#     {'nutrientId': 1279,
#      'nutrientName': '22:1',
#      'nutrientNumber': '630',
#      'unitName': 'G',
# ...
#      'value': 41.38},
#     {'nutrientId': 1079,
#      'nutrientName': 'Fiber, total dietary',
#      'nutrientNumber': '291',
#      'unitName': 'G',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'value': 0.0},
#     {'nutrientId': 1087,
#      'nutrientName': 'Calcium, Ca',
#      'nutrientNumber': '301',
#      'unitName': 'MG',
#      'derivationCode': 'LCSA',
#      'derivationDescription': 'Calculated from an approximate value per serving size measure',
#      'value': 6.0},
#     {'nutrientId': 1089,
#      'nutrientName': 'Iron, Fe',
#      'nutrientNumber': '303',
#      'unitName': 'MG',
#      'derivationCode': 'LCSA',
#      'derivationDescription': 'Calculated from an approximate value per serving size measure',
#      'value': 2.69},
#     {'nutrientId': 1092,
#      'nutrientName': 'Potassium, K',
#      'nutrientNumber': '306',
#      'unitName': 'MG',
#      'derivationCode': 'LCSA',
#      'derivationDescription': 'Calculated from an approximate value per serving size measure',
#      'value': 34.0},
#     {'nutrientId': 1093,
#      'nutrientName': 'Sodium, Na',
#      'nutrientNumber': '307',
#      'unitName': 'MG',
#      'derivationCode': 'LCSA',
#      'derivationDescription': 'Calculated from an approximate value per serving size measure',
#      'value': 276.0},
#     {'nutrientId': 1162,
#      'nutrientName': 'Vitamin C, total ascorbic acid',
#      'nutrientNumber': '401',
#      'unitName': 'MG',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'value': 0.0},
#     {'nutrientId': 1253,
#      'nutrientName': 'Cholesterol',
#      'nutrientNumber': '601',
#      'unitName': 'MG',
#      'derivationCode': 'LCSA',
#      'derivationDescription': 'Calculated from an approximate value per serving size measure',
#      'value': 0.0},
#     {'nutrientId': 1257,
#      'nutrientName': 'Fatty acids, total trans',
#      'nutrientNumber': '605',
#      'unitName': 'G',
#      'derivationCode': 'LCSA',
#      'derivationDescription': 'Calculated from an approximate value per serving size measure',
#      'value': 0.0},
#     {'nutrientId': 1258,
#      'nutrientName': 'Fatty acids, total saturated',
#      'nutrientNumber': '606',
#      'unitName': 'G',
#      'derivationCode': 'LCSA',
#      'derivationDescription': 'Calculated from an approximate value per serving size measure',
#      'value': 6.9}],
#    'allHighlightFields': '',
#    'score': -267.99713},
#   {'fdcId': 925788,
#    'description': 'CHOCOLATE DIPPED OREOS, CHOCOLATE',
#    'dataType': 'Branded',
#    'gtinUpc': '819354016861',
#    'publishedDate': '2020-05-28',
#    'brandOwner': 'California Fruit Exchange',
#    'ingredients': 'DOUBLE STUFFED OREO (SUGAR, UNBLEACHED FLOUR (WHEAT FLOUR, NIACIN, REDUCED IRON, THIAMINE MONONITRATE {VITAMIN B1}, RIBOFLAVIN {VITAMIN B2}. FOLIC ACID), PALM AND/OR CANOLA OIL, COCOA (PROCESSED WITH ALKALI), HIGH FRUCTOSE CORN SYRUP, LEAVENING (BAKING SODA AND/OR CALCIUM PHOSPHATE), SALT, SOY LECITHIN, CHOCOLATE, ARTIFICIAL FLAVOR), MILK CHOCOLATE (SUGAR, WHOLE MILK, COCOA BUTTER, CHOCOLATE LIQUOR, SOY LECITHIN (AN EMULSIFIER), VANILLIN (AN ARTIFICIAL FLAVOR)), DARK CHOCOLATE (SUGAR, CHOCOLATE LIQUOR (PROCESSED WITH ALKALI), COCOA BUTTER, MILK FAT, SOY LECITHIN (AN EMULSIFER), VANILLA, AND VANILLIN (AN ARTIFICIAL FLAVOR)), CRUSHED PEPPERMINT CANDY (CANE SUGAR, CORN SYRUP, NATURAL PEPPERMINT OIL FLAVOR, FD&C RED #40, FD&C RED #3, FD&C BLUE #1), LESS THAN 2% OF: WHITE CHOCOLATE DRIZZLE (SUGAR, COCOA BUTTER, WHOLE MILK POWDER, SOY LECITHIN ADDED AS AN EMULSIFIER AND NATURAL VANILLA FLAVOR))',
#    'foodNutrients': [{'nutrientId': 1003,
#      'nutrientName': 'Protein',
#      'nutrientNumber': '203',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'value': 3.33},
#     {'nutrientId': 1004,
#      'nutrientName': 'Total lipid (fat)',
#      'nutrientNumber': '204',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'value': 26.67},
#     {'nutrientId': 1005,
#      'nutrientName': 'Carbohydrate, by difference',
#      'nutrientNumber': '205',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'value': 63.33},
#     {'nutrientId': 1008,
#      'nutrientName': 'Energy',
#      'nutrientNumber': '208',
#      'unitName': 'KCAL',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'value': 500.0},
#     {'nutrientId': 2000,
#      'nutrientName': 'Sugars, total including NLEA',
#      'nutrientNumber': '269',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'value': 46.67},
#     {'nutrientId': 1079,
#      'nutrientName': 'Fiber, total dietary',
#      'nutrientNumber': '291',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'value': 10.0},
#     {'nutrientId': 1093,
#      'nutrientName': 'Sodium, Na',
#      'nutrientNumber': '307',
#      'unitName': 'MG',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'value': 183.0},
#     {'nutrientId': 1235,
#      'nutrientName': 'Sugars, added',
#      'nutrientNumber': '539',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'value': 26.7},
#     {'nutrientId': 1253,
#      'nutrientName': 'Cholesterol',
#      'nutrientNumber': '601',
#      'unitName': 'MG',
#      'derivationCode': 'LCSL',
#      'derivationDescription': 'Calculated from a less than value per serving size measure',
#      'value': 17.0},
#     {'nutrientId': 1257,
#      'nutrientName': 'Fatty acids, total trans',
#      'nutrientNumber': '605',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'value': 0.0},
#     {'nutrientId': 1258,
#      'nutrientName': 'Fatty acids, total saturated',
#      'nutrientNumber': '606',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'value': 13.33}],
#    'allHighlightFields': '<b>Ingredients</b>: DOUBLE STUFFED <em>OREO</em> (SUGAR, UNBLEACHED FLOUR (WHEAT FLOUR, NIACIN, REDUCED IRON, THIAMINE',
#    'score': -280.12527},
#   {'fdcId': 396439,
#    'description': 'FROZEN OREO DESSERT BAR',
#    'dataType': 'Branded',
#    'gtinUpc': '077567028747',
#    'publishedDate': '2019-04-01',
#    'brandOwner': 'Good Humor-Breyers Ice Cream',
#    'ingredients': 'NONFAT MILK, OREO CRUNCH {UNBLEACHED ENRICHED FLOUR [WHEAT FLOUR, NIACIN, REDUCED IRON, THIAMINE MONONITRATE (VITAMIN B1), RIBOFLAVIN (VITAMIN B2), FOLIC ACID], SUGAR, PALM AND/OR CANOLA OIL, COCOA (PROCESSED WITH ALKALI), HIGH FRUCTOSE CORN SYRUP, LEAVENING (BAKING SODA AND/OR CALCIUM PHOSPHATE), CORNSTARCH, SALT, SOY LECITHIN,VANILLIN - AN ARTIFICIAL FLAVOR, CHOCOLATE}, MILK CHOCOLATE FLAVORED COATING [SOYBEAN OIL, SUGAR, COCONUT OIL, CHOCOLATE (PROCESSED WITH ALKALI), MILK, WHEY, COCOA (PROCESSED WITH ALKALI), SOY LECITHIN, SALT, ARTIFICIAL FLAVOR], SUGAR, CORN SYRUP, OREO COOKIE PIECES {UNBLEACHED ENRICHED FLOUR [WHEAT FLOUR, NIACIN, REDUCED IRON, THIAMINE MONONITRATE (VITAMIN B1), RIBOFLAVIN (VITAMIN B2), FOLIC ACID], SUGAR, PALM AND/OR CANOLA OIL, COCOA (PROCESSED WITH ALKALI), HIGH FRUCTOSE CORN SYRUP, LEAVENING (BAKING SODA AND/OR CALCIUM PHOSPHATE), SALT, SOY LECITHIN, CHOCOLATE, ARTIFICIAL FLAVOR}, COCONUT OIL, LESS THAN 2% OF: WHEY, MONO AND DIGLYCERIDES, GUAR GUM, LOCUST BEAN GUM, NATURAL AND ARTIFICIAL FLAVOR, CARAMEL COLOR, VITAMIN A PALMITATE.',
#    'foodNutrients': [{'nutrientId': 1087,
#      'nutrientName': 'Calcium, Ca',
#      'nutrientNumber': '301',
#      'unitName': 'MG',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'value': 82.0},
#     {'nutrientId': 1089,
#      'nutrientName': 'Iron, Fe',
#      'nutrientNumber': '303',
#      'unitName': 'MG',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'value': 0.99},
#     {'nutrientId': 1104,
#      'nutrientName': 'Vitamin A, IU',
#      'nutrientNumber': '318',
#      'unitName': 'IU',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'value': 274.0},
#     {'nutrientId': 1162,
#      'nutrientName': 'Vitamin C, total ascorbic acid',
#      'nutrientNumber': '401',
#      'unitName': 'MG',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'value': 0.0},
#     {'nutrientId': 1253,
#      'nutrientName': 'Cholesterol',
#      'nutrientNumber': '601',
#      'unitName': 'MG',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'value': 0.0},
#     {'nutrientId': 1003,
#      'nutrientName': 'Protein',
#      'nutrientNumber': '203',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'value': 2.74},
#     {'nutrientId': 1004,
#      'nutrientName': 'Total lipid (fat)',
#      'nutrientNumber': '204',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'value': 15.07},
#     {'nutrientId': 1005,
#      'nutrientName': 'Carbohydrate, by difference',
#      'nutrientNumber': '205',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'value': 35.62},
#     {'nutrientId': 1008,
#      'nutrientName': 'Energy',
#      'nutrientNumber': '208',
#      'unitName': 'KCAL',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'value': 288.0},
#     {'nutrientId': 2000,
#      'nutrientName': 'Sugars, total including NLEA',
#      'nutrientNumber': '269',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'value': 23.29},
#     {'nutrientId': 1093,
#      'nutrientName': 'Sodium, Na',
#      'nutrientNumber': '307',
#      'unitName': 'MG',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'value': 137.0},
#     {'nutrientId': 1257,
#      'nutrientName': 'Fatty acids, total trans',
#      'nutrientNumber': '605',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'value': 0.0},
#     {'nutrientId': 1258,
#      'nutrientName': 'Fatty acids, total saturated',
#      'nutrientNumber': '606',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'value': 6.85},
#     {'nutrientId': 1079,
#      'nutrientName': 'Fiber, total dietary',
#      'nutrientNumber': '291',
#      'unitName': 'G',
#      'derivationCode': 'LCSL',
#      'derivationDescription': 'Calculated from a less than value per serving size measure',
#      'value': 1.4}],
#    'allHighlightFields': '<b>Ingredients</b>: NONFAT MILK, <em>OREO</em> CRUNCH {UNBLEACHED ENRICHED FLOUR [WHEAT FLOUR, NIACIN, REDUCED IRON, THIAMINE',
#    'score': -280.12527},
#   {'fdcId': 541035,
#    'description': 'NABISCO, OREO, CHOCOLATE PIE',
#    'dataType': 'Branded',
#    'gtinUpc': '4903015316172',
#    'publishedDate': '2019-04-01',
#    'brandOwner': 'NABISCO',
#    'ingredients': 'WHEAT FLOUR, SUGAR, PALM OIL, CACAO MASS MALTOSE, CORN SYRUP, WHOLE MILK POWDER, GLUCOSE, COCOA POWDER, COCOA BUTTER, CORN FLOUR, HIGH FRUCTOSE CORN SYRUP, EGG CONCENTRATED STRAWBERRY JUICE AGAR-AGAR, SALT. BAKING POWDER, ALCOHOL, CELLULOSE, EMULSIFIER (SOY LECITHIN), ARTIFICIAL FLAVOR.',
#    'foodNutrients': [{'nutrientId': 1079,
#      'nutrientName': 'Fiber, total dietary',
#      'nutrientNumber': '291',
#      'unitName': 'G',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'value': 0.0},
#     {'nutrientId': 1087,
#      'nutrientName': 'Calcium, Ca',
#      'nutrientNumber': '301',
#      'unitName': 'MG',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'value': 0.0},
#     {'nutrientId': 1089,
#      'nutrientName': 'Iron, Fe',
#      'nutrientNumber': '303',
#      'unitName': 'MG',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'value': 0.0},
#     {'nutrientId': 1104,
#      'nutrientName': 'Vitamin A, IU',
#      'nutrientNumber': '318',
#      'unitName': 'IU',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'value': 0.0},
#     {'nutrientId': 1162,
#      'nutrientName': 'Vitamin C, total ascorbic acid',
#      'nutrientNumber': '401',
#      'unitName': 'MG',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'value': 0.0},
#     {'nutrientId': 1253,
#      'nutrientName': 'Cholesterol',
#      'nutrientNumber': '601',
#      'unitName': 'MG',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'value': 0.0},
#     {'nutrientId': 1258,
#      'nutrientName': 'Fatty acids, total saturated',
#      'nutrientNumber': '606',
#      'unitName': 'G',
#      'derivationCode': 'LCCD',
#      'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#      'value': 0.0},
#     {'nutrientId': 1003,
#      'nutrientName': 'Protein',
#      'nutrientNumber': '203',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'value': 8.33},
#     {'nutrientId': 1004,
#      'nutrientName': 'Total lipid (fat)',
#      'nutrientNumber': '204',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'value': 18.75},
#     {'nutrientId': 1005,
#      'nutrientName': 'Carbohydrate, by difference',
#      'nutrientNumber': '205',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'value': 62.5},
#     {'nutrientId': 1008,
#      'nutrientName': 'Energy',
#      'nutrientNumber': '208',
#      'unitName': 'KCAL',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'value': 458.0},
#     {'nutrientId': 2000,
#      'nutrientName': 'Sugars, total including NLEA',
#      'nutrientNumber': '269',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'value': 62.5},
#     {'nutrientId': 1093,
#      'nutrientName': 'Sodium, Na',
#      'nutrientNumber': '307',
#      'unitName': 'MG',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'value': 375.0},
#     {'nutrientId': 1257,
#      'nutrientName': 'Fatty acids, total trans',
#      'nutrientNumber': '605',
#      'unitName': 'G',
#      'derivationCode': 'LCCS',
#      'derivationDescription': 'Calculated from value per serving size measure',
#      'value': 0.0}],
#    'allHighlightFields': '',
#    'score': -280.12527}]}
